# %%
# ============================================
# CAPSTONE PROJECT NOTEBOOK
# Analisis Feedback Digitalisasi Layanan BUMN
# Aplikasi: BRImo, Livin Mandiri, MyTelkomsel
# ============================================

# ================
# 1. Import Library
# ================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os


filename = "C:/Users/LENOVO/OneDrive/Desktop/Bumn-Reviews/data/bumn_reviews.csv"

# cek apakah file ada
if not os.path.exists(filename):
    raise FileNotFoundError(f"File {filename} tidak ditemukan. Pastikan path sudah benar!")


df = pd.read_csv(filename)


df = df[['app', 'content', 'score', 'at']]

print("✅ Dataset berhasil dimuat")
print("Jumlah data:", len(df))
df.head()
# Out:
# ✅ Dataset berhasil dimuat
# Jumlah data: 3000
#      app                                            content  score  \
# 0  BRImo  mudah dalam setiap transaksi brimo sangat memb...      5
# 1  BRImo              keren... Aplikasi yang sangat praktis      5
# 2  BRImo  uang cuma ada 500 ribu doang, terus mau trf k ...      1
# 3  BRImo  bagus tapi plis jangan kebanyakan update, peny...      5
# 4  BRImo                                              mudah      5
#
#                     at
# 0  2025-09-05 11:30:12
# 1  2025-09-05 11:27:26
# 2  2025-09-05 11:23:24
# 3  2025-09-05 11:17:36
# 4  2025-09-05 11:15:23
